# %% [markdown]
# <a href="https://colab.research.google.com/github/cloeamion/BTE320/blob/main/BTE_320F_notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello')
# Out:
# Hello

# %%
5+3.0
# Out:
# 8.0

# %%
1-2
# Out:
# -1

# %%
2*3
# Out:
# 6

# %%
6/3
# Out:
# 2.0

# %%
6//4
# Out:
# 1

# %%
6.0//4.0
# Out:
# 1.0

# %%
2**3
# Out:
# 8

# %%
5%3
# Out:
# 2

# %%
6%3
# Out:
# 0

# %%
1%3
# Out:
# 1

# %%
2%3
# Out:
# 2

# %%
x=2

# %%
x=3


x==2
x!=2
x>2
x<2
x<=2
x>=2
# Out:
# True
